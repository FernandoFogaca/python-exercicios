# %% [markdown]
# ## Exercicío 01

# %%
# Dados Do Estágiario


nome_estagiario = "Fernando Padilha Fogaça"
idade_estagiario = 38
codigo_departamento = "GRLADS01C2-N2-L1"


print(" Registro do Estágiario ")
print()
print(f'Nome: {nome_estagiario}')
print(f'Idade: {idade_estagiario}')
print(f'Classe: {codigo_departamento}')
# Out:
#  Registro do Estágiario
#
# Nome: Fernando Padilha Fogaça
# Idade: 38
# Classe: GRLADS01C2-N2-L1

# %% [markdown]
# ##Exercicío 02

# %%
## Análise de Crédito


nome_cliente = "Fernando Padilha Fogaça"
idade_cliente = 38
score_credito = 772.40
cliente_ativo = True


print(" Sistema de Análises de Crédito ")
print()
print(f'Nome : {nome_cliente}')
print(type(nome_cliente))
print()
print(f'Idade: {idade_cliente}')
print(type(idade_cliente))
print()
print(f'Score {score_credito}')
print(type(score_credito))
print()
print(f'Cliente ativo {cliente_ativo}')
print(type(cliente_ativo))
# Out:
#  Sistema de Análises de Crédito
#
# Nome : Fernando Padilha Fogaça
# <class 'str'>
#
# Idade: 38
# <class 'int'>
#
# Score 772.4
# <class 'float'>
#
# Cliente ativo True
# <class 'bool'>

# %% [markdown]
# ## Exercicío 03

# %%
## Calculo


km_por_dia = 38
gasto_diario = 300 + 88

print(" Calculo de Quilometragem ")
print()
print(f'Total em uma semana {km_por_dia * 7}')
print()
print(f'Diferença entre R$ 100 reais e o gasto diário{100 - gasto_diario }')
print()
print(f'Quantos dias o valor de R$ 500.00 cobre {500 // gasto_diario}')
print()
print(f'Porcentagem do gasto diário em relação a 100 {gasto_diario % 100}')
print()
print(f'Média diária de custo por km {gasto_diario / km_por_dia}')
# Out:
#  Calculo de Quilometragem
#
# Total em uma semana 266
#
# Diferença entre R$ 100 reais e o gasto diário-288
#
# Quantos dias o valor de R$ 500.00 cobre 1
#
# Porcentagem do gasto diário em relação a 100 88
#
# Média diária de custo por km 10.210526315789474

# %% [markdown]
# ## Exercicío 04

# %%
tempo_minutos = 150 + 88
tempo__horas = 2.25



print("Painel de Produtividade")
print()
print(f'Calculo de  quantas horas equivalem  a tempo minutos {tempo_minutos / 60:.2f}')
print()
print(f'Calculo de quantos minutos equivalem a tempo horas {tempo__horas * 60:.2f}')
# Out:
# Painel de Produtividade
#
# Calculo de  quantas horas equivalem  a tempo minutos 3.97
#
# Calculo de quantos minutos equivalem a tempo horas 135.00

# %% [markdown]
# ## Exercicío 05

# %%
## Formata Relatórios


msg_aspas_simples = 'Tech Mythology'
msg_aspas_duplas = "Fernando Fogaça"

relatorio_triple = """Título: Tech Mythology\nDescrição: Sistema de análise em Python\nStatus:em desenvolvimento"""


print(" Formata retlatórios")
print()
print(f'Proejto {msg_aspas_simples} em execução')
print()
print(f'Aluno {msg_aspas_duplas} aprovado no teste.')
print()
print(relatorio_triple)
# Out:
#  Formata retlatórios
#
# Proejto Tech Mythology em execução
#
# Aluno Fernando Fogaça aprovado no teste.
#
# Título: Tech Mythology
# Descrição: Sistema de análise em Python
# Status:em desenvolvimento

# %% [markdown]
# ## Exercicío 06

# %%
## Mensagem Automática


name = "Fernando"
surname = "Fogaça!"
course_code = "GRLADS01C2-N2-L1"

print("Welcome,",name + " " + surname + "  Your course code is " + course_code)
# Out:
# Welcome, Fernando Fogaça!  Your course code is GRLADS01C2-N2-L1

# %% [markdown]
# ## Exercicío 07

# %%
## Mensagens Repetidas...


alerta = "\033[31mATENÇÃO!\033[0m "
faixa_alerta = alerta *5

print(faixa_alerta)
# Out:
# ATENÇÃO! ATENÇÃO! ATENÇÃO! ATENÇÃO! ATENÇÃO!

# %% [markdown]
# ## Exercicío 08

# %%
## Padroniza Nomes...


nome_completo = "Fernando Padilha Fogaça"


print("Padronizando...")
print()
print(nome_completo.upper())
print()
print(nome_completo.lower())
print()
print(nome_completo.title())
print()
print(nome_completo.capitalize())
print()
print(nome_completo.swapcase())
# Out:
# Padronizando...
#
# FERNANDO PADILHA FOGAÇA
#
# fernando padilha fogaça
#
# Fernando Padilha Fogaça
#
# Fernando padilha fogaça
#
# fERNANDO pADILHA fOGAÇA

# %% [markdown]
# ## Exercicío 09

# %%
## Ferramenta de Filtragem..


habilidades = "Dominio em Python,SQL e Excel"
busca = "Python"



print(f'A palavra {busca} está em habilidades:{busca in habilidades} ')
# Out:
# A palavra Python está em habilidades:True

# %% [markdown]
# ## Exercicío 10

# %%
## Conta caracteres

opiniao = "Serviço excelente, aluno Fernando Padilha Fogaça, voltarei a comprar!"




print("Palavras  e Caracteres")
print()
print(f'Há {len(opiniao)} caracteres na frase:\n{opiniao}')
print()
print(f'E  essa frase contém {len(opiniao.split())} palavras')
# Out:
# Palavras  e Caracteres
#
# Há 69 caracteres na frase:
# Serviço excelente, aluno Fernando Padilha Fogaça, voltarei a comprar!
#
# E  essa frase contém 9 palavras

# %% [markdown]
# ##Exercicío 11

# %%
## Converter


ano_txt = "1988"
ano_int = int(ano_txt)


print(f'Ano de nascimento: {ano_int}')
print()
soma = ano_int + 5
print(f'Somasse 5 ao valor convertido e imprima o resultado: {soma}')
print()
# Out:
# Ano de nascimento: 1988
#
# Somasse 5 ao valor convertido e imprima o resultado: 1993

# %% [markdown]
# ##Exercicío 12

# %%
## Campanha de Desconto


desconto_txt = "38"

desconto_num = (float(desconto_txt) /3.14)/100

valor = 599.99

valor_desconto = valor * desconto_num

valor_final = valor - valor_desconto

print(f'O valor orginal do Óculos R${valor:.2f}')
print(f'O valor do desconto é de {valor_desconto:.2f} %' )
print()
print(f'Valor final: {valor_final:.2f}')
# Out:
# O valor orginal do Óculos R$599.99
# O valor do desconto é de 72.61 %
#
# Valor final: 527.38
